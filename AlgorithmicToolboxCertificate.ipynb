# %% [markdown]
# ## **Notebook for show the Algorithmic Toolbox Certificate**
#
# *Name: Ángel Mateo González Bejarano*
#
# Algorithms. UNAL

# %% [markdown]
# -----
#
# You can visit my [LinkedIn](https://www.linkedin.com/in/angegonzalez/) but here I will show you the certificate

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
